# %% [markdown]
# # Modélisation de la perfomance du portfolio

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import requests
from bs4 import BeautifulSoup
import math
from tqdm import tqdm
from itertools import islice
import seaborn as sns
import time

# %% [markdown]
# ### Précicer les paths

# %%
# définir le path vers les 3 fichiers
path = r'...'


path_list = path + r'\List stock Paris.xlsx'
path_rend = path + r'\rendements.csv'
path_param = path + r'\param.csv'

# %%
# fonction requete pour yfinance
def get_stock(dico,final_tab):
    names,miss = list(dico.keys()), []
    for firm in tqdm(names):
        try:
            code = dico[firm]
            tick = yf.Ticker(code)
            hist = tick.history(period = 'max')
            hist.index = hist.index.strftime('%Y-%m-%d')
            hist = hist.loc['2000-01-03':'2023-12-31','Close']
            hist = hist.to_frame(name =firm)
            final_tab = pd.concat([final_tab,hist],axis = 1)
        except:
            miss.append(firm)
        time.sleep(0.5)
    return final_tab,miss

# %%
#On considère 900 stocks de euronext Paris

stock_list = pd.read_excel(path_list)
all_stocks = {}
for i in range(len(stock_list)):
    all_stocks[stock_list.iloc[i,1]] = stock_list.iloc[i,2] + ".PA"
    
len(all_stocks)
# Out:
# 844

# %% [markdown]
# ### Construction initiale de la table de rendements mensuels avec yfinance

# %%
# ## La première fois on reconstruit une table de valeurs de stocks à partir de yahoo finance

# tick = yf.Ticker('^N100')
# hist = tick.history(period = 'max')
# hist.index = hist.index.strftime('%Y-%m-%d')
# hist = hist.loc['1999-12-29':'2024-11-28','High']
# final_tab = hist.to_frame(name ='EURONEXT 100')
# final_tab,miss = get_stock(all_stocks,final_tab)
# final_tab.index = pd.to_datetime(final_tab.index)
# moyennes_mois = final_tab.resample('M').mean()
# rendements = moyennes_mois.pct_change().iloc[2:,:]
# Out:
#   3%|██                                                                               | 22/844 [00:19<12:23,  1.11it/s]ADUX.PA: No data found, symbol may be delisted
#   3%|██▌                                                                              | 27/844 [00:24<11:32,  1.18it/s]AFMBS.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#   5%|████                                                                             | 42/844 [00:37<12:14,  1.09it/s]ALD.PA: No data found, symbol may be delisted
#   5%|████▏                                                                            | 43/844 [00:38<13:27,  1.01s/it]ALGRE.PA: No data found, symbol may be delisted
#   6%|████▉                                                                            | 52/844 [00:47<13:10,  1.00it/s]$ALTUR.PA: possibly delisted; No timezone found
#   7%|█████▊                                                                           | 60/844 [00:54<10:00,  1.31it/s]$APAM.PA: possibly delisted; No timezone found
#   7%|█████▊                                                                           | 61/844 [00:55<11:34,  1.13it/s]MLASO.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#   8%|██████▌                                                                          | 69/844 [01:02<11:03,  1.17it/s]MLARE.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#   9%|███████▍                                                                         | 78/844 [01:09<11:14,  1.14it/s]ARVBS.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  10%|███████▊                                                                         | 81/844 [01:12<10:52,  1.17it/s]MLAST.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  10%|████████▍                                                                        | 88/844 [01:18<11:40,  1.08it/s]$MLAUD.PA: possibly delisted; No timezone found
#  12%|█████████▋                                                                      | 102/844 [01:32<11:31,  1.07it/s]MLBAR.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  12%|█████████▉                                                                      | 105/844 [01:35<11:46,  1.05it/s]$MLBAT.PA: possibly delisted; No timezone found
#  14%|███████████▏                                                                    | 118/844 [01:47<10:57,  1.10it/s]BPBS.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  14%|███████████▎                                                                    | 119/844 [01:48<09:43,  1.24it/s]$BIOS.PA: possibly delisted; No timezone found
#  17%|█████████████▎                                                                  | 141/844 [02:10<10:53,  1.08it/s]$MLAAE.PA: possibly delisted; No timezone found
#  18%|██████████████▌                                                                 | 153/844 [02:22<12:22,  1.07s/it]CATR.PA: No data found, symbol may be delisted
#  18%|██████████████▋                                                                 | 155/844 [02:24<11:18,  1.02it/s]$CBIBS.PA: possibly delisted; No timezone found
#  19%|███████████████                                                                 | 159/844 [02:28<10:49,  1.06it/s]$CYAD.PA: possibly delisted; No timezone found
#  19%|███████████████▍                                                                | 163/844 [02:32<11:24,  1.01s/it]CGG.PA: No data found, symbol may be delisted
#  20%|████████████████▍                                                               | 173/844 [02:43<11:36,  1.04s/it]$MLCIO.PA: possibly delisted; No timezone found
#  23%|██████████████████                                                              | 190/844 [02:58<09:47,  1.11it/s]MLCOE.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  25%|████████████████████▎                                                           | 214/844 [03:22<11:02,  1.05s/it]CYBK1.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  25%|████████████████████▍                                                           | 215/844 [03:23<09:33,  1.10it/s]CYBKA.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  26%|████████████████████▍                                                           | 216/844 [03:23<08:25,  1.24it/s]CYBKB.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  27%|█████████████████████▉                                                          | 232/844 [03:39<10:30,  1.03s/it]DMSBS.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  28%|██████████████████████▏                                                         | 234/844 [03:40<09:15,  1.10it/s]$ALIMG.PA: possibly delisted; No timezone found
#  28%|██████████████████████▋                                                         | 240/844 [03:46<08:47,  1.15it/s]BNBS.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  32%|█████████████████████████▍                                                      | 268/844 [04:11<07:50,  1.22it/s]ALENE.PA: No data found, symbol may be delisted
#  32%|█████████████████████████▌                                                      | 270/844 [04:14<09:56,  1.04s/it]$ALENI.PA: possibly delisted; No timezone found
#  33%|██████████████████████████▎                                                     | 278/844 [04:22<09:26,  1.00s/it]$ALPLA.PA: possibly delisted; No timezone found
#  33%|██████████████████████████▍                                                     | 279/844 [04:23<10:43,  1.14s/it]$ESI.PA: possibly delisted; No timezone found
#  34%|███████████████████████████                                                     | 286/844 [04:31<09:50,  1.06s/it]$EUR.PA: possibly delisted; No timezone found
#  35%|███████████████████████████▋                                                    | 292/844 [04:37<10:05,  1.10s/it]MLCAN.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  36%|████████████████████████████▉                                                   | 305/844 [04:49<08:10,  1.10it/s]MLECE.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  37%|█████████████████████████████▍                                                  | 311/844 [04:55<08:40,  1.02it/s]FALG.PA: No data found, symbol may be delisted
#  37%|█████████████████████████████▉                                                  | 316/844 [05:00<08:19,  1.06it/s]BERR.PA: No data found, symbol may be delisted
#  39%|██████████████████████████████▉                                                 | 327/844 [05:11<07:17,  1.18it/s]ALFOC.PA: No data found, symbol may be delisted
#  42%|█████████████████████████████████▎                                              | 352/844 [05:37<09:31,  1.16s/it]GNE.PA: No data found, symbol may be delisted
#  42%|█████████████████████████████████▋                                              | 355/844 [05:40<08:37,  1.06s/it]$GV.PA: possibly delisted; No timezone found
#  43%|██████████████████████████████████▎                                             | 362/844 [05:47<08:33,  1.07s/it]MLGLA.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  43%|██████████████████████████████████▌                                             | 364/844 [05:49<06:43,  1.19it/s]$MLGLW.PA: possibly delisted; No timezone found
#  43%|██████████████████████████████████▋                                             | 366/844 [05:51<07:43,  1.03it/s]MLNDG.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  47%|█████████████████████████████████████▎                                          | 393/844 [06:16<06:37,  1.13it/s]MLHAY.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  49%|███████████████████████████████████████▏                                        | 414/844 [06:37<06:23,  1.12it/s]ALHYG.PA: No data found, symbol may be delisted
#  52%|█████████████████████████████████████████▊                                      | 441/844 [07:03<07:03,  1.05s/it]MLINM.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  52%|█████████████████████████████████████████▉                                      | 442/844 [07:04<06:13,  1.08it/s]MLISP.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  54%|███████████████████████████████████████████                                     | 454/844 [07:15<05:47,  1.12it/s]$MLIOC.PA: possibly delisted; No timezone found
#  54%|███████████████████████████████████████████▏                                    | 455/844 [07:16<06:29,  1.00s/it]MLIPO.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  55%|███████████████████████████████████████████▋                                    | 461/844 [07:22<06:04,  1.05it/s]ITE.PA: No data found, symbol may be delisted
#  55%|████████████████████████████████████████████                                    | 465/844 [07:27<08:17,  1.31s/it]MLJSA.PA: No data found, symbol may be delisted
#  61%|█████████████████████████████████████████████████▏                              | 519/844 [08:21<05:02,  1.07it/s]MASBS.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  62%|█████████████████████████████████████████████████▌                              | 523/844 [08:25<05:06,  1.05it/s]MCPHY.PA: No data found, symbol may be delisted
#  62%|█████████████████████████████████████████████████▋                              | 524/844 [08:27<06:24,  1.20s/it]$MLMDV.PA: possibly delisted; No timezone found
#  63%|██████████████████████████████████████████████████                              | 528/844 [08:31<05:18,  1.01s/it]$ALKER.PA: possibly delisted; No timezone found
#  63%|██████████████████████████████████████████████████▎                             | 531/844 [08:34<04:59,  1.04it/s]MLMCE.PA: No data found, symbol may be delisted
#  63%|██████████████████████████████████████████████████▌                             | 534/844 [08:38<05:44,  1.11s/it]MLMIV.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  65%|████████████████████████████████████████████████████                            | 549/844 [08:51<04:28,  1.10it/s]$ALBUD.PA: possibly delisted; No timezone found
#  65%|████████████████████████████████████████████████████▏                           | 550/844 [08:52<05:05,  1.04s/it]ALMND.PA: No data found, symbol may be delisted
#  70%|███████████████████████████████████████████████████████▋                        | 587/844 [09:26<04:03,  1.06it/s]MLOKP.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  70%|███████████████████████████████████████████████████████▋                        | 588/844 [09:26<03:33,  1.20it/s]OLG.PA: No data found, symbol may be delisted
#  70%|████████████████████████████████████████████████████████▍                       | 595/844 [09:33<04:03,  1.02it/s]MLORB.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  71%|████████████████████████████████████████████████████████▊                       | 599/844 [09:36<03:18,  1.23it/s]ORP.PA: No data found, symbol may be delisted
#  71%|█████████████████████████████████████████████████████████                       | 602/844 [09:39<03:28,  1.16it/s]ALOSM.PA: No data found, symbol may be delisted
#  73%|██████████████████████████████████████████████████████████▍                     | 617/844 [09:53<03:36,  1.05it/s]$ALPHS.PA: possibly delisted; No timezone found
#  74%|██████████████████████████████████████████████████████████▉                     | 622/844 [09:59<04:06,  1.11s/it]VACBS.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  74%|███████████████████████████████████████████████████████████                     | 623/844 [10:00<03:29,  1.05it/s]VACBT.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  74%|███████████████████████████████████████████████████████████▎                    | 626/844 [10:03<03:40,  1.01s/it]$ALPIX.PA: possibly delisted; No timezone found
#  75%|███████████████████████████████████████████████████████████▌                    | 629/844 [10:06<03:42,  1.04s/it]$PATBS.PA: possibly delisted; No timezone found
#  75%|███████████████████████████████████████████████████████████▊                    | 631/844 [10:08<03:54,  1.10s/it]POM.PA: No data found, symbol may be delisted
#  76%|████████████████████████████████████████████████████████████▊                   | 642/844 [10:19<03:05,  1.09it/s]PROBT.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  78%|██████████████████████████████████████████████████████████████▏                 | 656/844 [10:32<03:07,  1.00it/s]MLJDL.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  79%|███████████████████████████████████████████████████████████████                 | 665/844 [10:40<02:46,  1.08it/s]ROCBT.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  80%|███████████████████████████████████████████████████████████████▌                | 671/844 [10:47<03:07,  1.08s/it]MLSAG.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  81%|████████████████████████████████████████████████████████████████▋               | 682/844 [10:58<02:45,  1.02s/it]SLB.PA: No data found, symbol may be delisted
#  82%|█████████████████████████████████████████████████████████████████▉              | 696/844 [11:11<02:12,  1.12it/s]$SESL.PA: possibly delisted; No timezone found
#  83%|██████████████████████████████████████████████████████████████████▎             | 700/844 [11:16<02:21,  1.02it/s]$SII.PA: possibly delisted; No timezone found
#  83%|██████████████████████████████████████████████████████████████████▌             | 702/844 [11:18<02:25,  1.03s/it]MLMAT.PA: No data found, symbol may be delisted
#  84%|██████████████████████████████████████████████████████████████████▉             | 706/844 [11:22<02:08,  1.07it/s]$SMLBS.PA: possibly delisted; No timezone found
#  85%|████████████████████████████████████████████████████████████████████            | 718/844 [11:34<02:13,  1.06s/it]$SOLB.PA: possibly delisted; No timezone found
#  87%|█████████████████████████████████████████████████████████████████████▍          | 733/844 [11:49<01:52,  1.01s/it]STWBS.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  87%|█████████████████████████████████████████████████████████████████████▌          | 734/844 [11:50<01:37,  1.13it/s]$STRBS.PA: possibly delisted; No timezone found
#  87%|█████████████████████████████████████████████████████████████████████▉          | 738/844 [11:54<01:57,  1.11s/it]$SYENS.PA: possibly delisted; No timezone found
#  88%|██████████████████████████████████████████████████████████████████████▍         | 743/844 [12:01<02:15,  1.34s/it]$TCHCS.PA: possibly delisted; No timezone found
#  90%|████████████████████████████████████████████████████████████████████████        | 760/844 [12:18<01:13,  1.15it/s]TIPI.PA: No data found, symbol may be delisted
#  90%|████████████████████████████████████████████████████████████████████████▏       | 761/844 [12:19<01:20,  1.03it/s]$TITC.PA: possibly delisted; No timezone found
#  90%|████████████████████████████████████████████████████████████████████████▎       | 763/844 [12:21<01:18,  1.03it/s]$TMBSY.PA: possibly delisted; No timezone found
#  92%|█████████████████████████████████████████████████████████████████████████▋      | 777/844 [12:37<01:05,  1.03it/s]ALTTI.PA: No data found, symbol may be delisted
#  94%|███████████████████████████████████████████████████████████████████████████▏    | 793/844 [12:52<00:49,  1.04it/s]VKBS.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  94%|███████████████████████████████████████████████████████████████████████████▎    | 795/844 [12:54<00:41,  1.17it/s]MLVRE.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  94%|███████████████████████████████████████████████████████████████████████████▌    | 797/844 [12:56<00:42,  1.09it/s]VANBS.PA: No data found, symbol may be delisted
#  95%|███████████████████████████████████████████████████████████████████████████▋    | 798/844 [12:57<00:49,  1.08s/it]$MLVAZ.PA: possibly delisted; No timezone found
#  97%|█████████████████████████████████████████████████████████████████████████████▎  | 815/844 [13:14<00:27,  1.06it/s]ALVIV.PA: No data found, symbol may be delisted
#  97%|█████████████████████████████████████████████████████████████████████████████▎  | 816/844 [13:15<00:28,  1.02s/it]VIVBS.PA: No data found, symbol may be delisted
#  97%|█████████████████████████████████████████████████████████████████████████████▍  | 817/844 [13:16<00:30,  1.13s/it]ALVMG.PA: No data found, symbol may be delisted
#  98%|██████████████████████████████████████████████████████████████████████████████  | 824/844 [13:24<00:20,  1.02s/it]MLVRF.PA: Period 'max' is invalid, must be one of ['1d', '5d']
#  98%|██████████████████████████████████████████████████████████████████████████████▊ | 831/844 [13:30<00:12,  1.06it/s]MLWEL.PA: No data found, symbol may be delisted
# 100%|███████████████████████████████████████████████████████████████████████████████▋| 841/844 [13:38<00:02,  1.21it/s]$XILDS.PA: possibly delisted; No timezone found
# 100%|████████████████████████████████████████████████████████████████████████████████| 844/844 [13:41<00:00,  1.03it/s]

# %%
# print (f'impossible de récupérer les données pour : {miss}')
# print(f'{len(rendements)} récupérée')
# rendements.head()
# Out:
# impossible de récupérer les données pour : ['Adux', 'Affluent Med Bsar', 'Ald', 'Algreen', 'Altur Invest.', 'Aperam', 'Apodaca Inversione', 'Aref Thalassa', 'Arverne Warrant', 'Astickso Xxi', 'Audience Labs', 'Barings Core Spain', 'Batla Minerals', 'Biophytis Bsa', 'Biosenic', 'Caire', 'Caterpillar Inc', 'Cbi Bsa', 'Celyad Oncology', 'Cgg', 'Cioa', 'Core Spain Holdco', 'Cybergun Bsa K1', 'Cybergun Bsa K2A', 'Cybergun Bsa K2B', 'Diagnostic Med Bsa', 'Dms Imaging', 'Drone Volt Bs26', 'Enertime', 'Eniblock', 'Erold', 'Esi Group', 'Euro Ressources', 'Eurolog Canola', 'Faifey Invest', 'Fermentalg', 'Fin.Etang Berre', 'Focusentertainment', 'General Electric', 'Genomic Vision', 'Glass To Power A', 'Glass To Power War', 'Global Pielago', 'Healthcare Activos', 'Hybrigenics', 'Inmark', 'Inmosupa', 'Ioc Holding', 'Iposa Properties', 'Itesoft', 'Jsa Technology', 'Mastrad Bs29', 'Mcphy Energy', 'Mdv', 'Media Maker', 'Mediocredito Europ', 'Meridia Re Iv', 'Mint', 'Mnd', 'Ok Properties', 'Ol Groupe', 'Orbis Properties', 'Orpea', 'Osmozis', 'Pharmasimple', 'Pierre Vac Bsa Act', 'Pierre Vac Bsa Cre', 'Pixium Vision', 'Plant Advanced Bs', 'Plastic Omnium', 'Prologue Bsa', 'Res Gestae Socimi', 'Roctool Bsa 2020-2', 'Sagax Real Estate', 'Schlumberger', 'Ses Imagotag', 'Sii', 'Simat', 'Smalto Bsa', 'Solvay', 'Streamwide Bs25', 'Streamwide Bs25-2', 'Syensqo', 'Technicolor Cs', 'Tipiak', 'Titan Cement', 'Tme Pharma Bsa Y', 'Tti', 'Vallourec Bsa 21', 'Vandor Real Estate', 'Vantiva Bsa 2024', 'Vaziva', 'Visiativ', 'Visiativ Bs', 'Visiomed Group', 'Vref Seville', 'Well', 'Xilam Animation Ds']
# 298 récupérée
#             EURONEXT 100  1000Mercis  2Crsi  A.S.T. Groupe  Ab Science  \
# Date
# 2000-02-29      0.045453         NaN    NaN            NaN         NaN
# 2000-03-31      0.033593         NaN    NaN            NaN         NaN
# 2000-04-30     -0.014503         NaN    NaN            NaN         NaN
# 2000-05-31      0.029108         NaN    NaN            NaN         NaN
# 2000-06-30      0.029065         NaN    NaN            NaN         NaN
#
#             Abc Arbitrage  Abeo  Abionyx Pharma  Abivax  Abl Diagnostics  ...  \
# Date                                                                      ...
# 2000-02-29       0.246351   NaN             NaN     NaN              NaN  ...
# 2000-03-31      -0.034140   NaN             NaN     NaN              NaN  ...
# 2000-04-30      -0.032412   NaN             NaN     NaN              NaN  ...
# 2000-05-31       0.048729   NaN             NaN     NaN              NaN  ...
# 2000-06-30      -0.030695   NaN             NaN     NaN              NaN  ...
#
#             Weya  Whiteni R Cajal  Winfarm  Witbe  Wiziboat  Worldline  X-Fab  \
# Date
# 2000-02-29   NaN              NaN      NaN    NaN       NaN        NaN    NaN
# 2000-03-31   NaN              NaN      NaN    NaN       NaN        NaN    NaN
# 2000-04-30   NaN              NaN      NaN    NaN       NaN        NaN    NaN
# 2000-05-31   NaN              NaN      NaN    NaN       NaN        NaN    NaN
# 2000-06-30   NaN              NaN      NaN    NaN       NaN        NaN    NaN
#
#             Xilam Animation  Zccm  Zci Limited
# Date
# 2000-02-29              NaN   NaN          NaN
# 2000-03-31              NaN   NaN          NaN
# 2000-04-30              NaN   NaN          NaN
# 2000-05-31              NaN   NaN          NaN
# 2000-06-30              NaN   NaN          NaN
#
# [5 rows x 747 columns]

# %%
# #On ajoute les obligations du trésor français

# obli_1M = pd.read_excel(r'C:\Users\ludo1\OneDrive\Bureau\Nimp\France 1M bond.xlsx')
# obli_1M.set_index(obli_1M.columns[0], inplace=True)
# obli_1M.columns = ['Obli']

# obli = pd.concat([obli_1M.iloc[:,0], pd.Series([3.5] * 6)], ignore_index=True)
# obli = ((1 + obli/100)**(1/12) - 1).reset_index(drop=True)
# obli.index = rendements.index


# rendements['Obli'] = obli

# #On sauvegarde le fichier après cette première construction
# rendements.to_csv(r'C:\Users\ludo1\OneDrive\Documents\Centrale\Portfolio_management\rendements.csv', index=True)

# %% [markdown]
# ### Utilisation de la table une fois construite

# %%
rendements = pd.read_csv(path_rend)

rendements.index = rendements['Date']
rendements = rendements.iloc[:,1:]
#On retrouve Euronext100 en première colonne et les obligations à la fin
rendements.head()
# Out:
#             EURONEXT 100  1000Mercis  2Crsi  A.S.T. Groupe  Ab Science  \
# Date
# 2000-02-29      0.045453         NaN    NaN            NaN         NaN
# 2000-03-31      0.033593         NaN    NaN            NaN         NaN
# 2000-04-30     -0.014503         NaN    NaN            NaN         NaN
# 2000-05-31      0.029108         NaN    NaN            NaN         NaN
# 2000-06-30      0.029065         NaN    NaN            NaN         NaN
#
#             Abc Arbitrage  Abeo  Abionyx Pharma  Abivax  Abl Diagnostics  ...  \
# Date                                                                      ...
# 2000-02-29       0.246351   NaN             NaN     NaN              NaN  ...
# 2000-03-31      -0.034140   NaN             NaN     NaN              NaN  ...
# 2000-04-30      -0.032412   NaN             NaN     NaN              NaN  ...
# 2000-05-31       0.048729   NaN             NaN     NaN              NaN  ...
# 2000-06-30      -0.030695   NaN             NaN     NaN              NaN  ...
#
#             Whiteni R Cajal  Winfarm  Witbe  Wiziboat  Worldline  X-Fab  \
# Date
# 2000-02-29              NaN      NaN    NaN       NaN        NaN    NaN
# 2000-03-31              NaN      NaN    NaN       NaN        NaN    NaN
# 2000-04-30              NaN      NaN    NaN       NaN        NaN    NaN
# 2000-05-31              NaN      NaN    NaN       NaN        NaN    NaN
# 2000-06-30              NaN      NaN    NaN       NaN        NaN    NaN
#
#             Xilam Animation  Zccm  Zci Limited      Obli
# Date
# 2000-02-29              NaN   NaN          NaN  0.002578
# 2000-03-31              NaN   NaN          NaN  0.002683
# 2000-04-30              NaN   NaN          NaN  0.002831
# 2000-05-31              NaN   NaN          NaN  0.003048
# 2000-06-30              NaN   NaN          NaN  0.003357
#
# [5 rows x 748 columns]

# %% [markdown]
# ### Construction initiale de la table de parametre avec yfinance

# %%
stocks = list( rendements.columns)

#Exemple de récupération d'information avec info

ticker = all_stocks['1000Mercis']
tick = yf.Ticker(ticker)
info = tick.info

# Affichage de quelques caractéristiques importantes
print("Nom:", info['longName'])
print("Secteur:", info['sector'])
print("Industrie:", info['industry'])
print("Prix actuel:", info['currentPrice'])

# Indicateurs financiers importants
print("PER (Price-to-Earnings):", info.get('trailingPE'))
print("Ratio cours/valeur comptable (P/B):", info.get('priceToBook'))
print("Croissance du chiffre d'affaires:", info.get('revenueGrowth'))
print("Rendement du dividende:", info.get('dividendYield'))
print("ROE (Return on Equity):", info.get('returnOnEquity'))
# Out:
# Nom: 1000mercis
# Secteur: Communication Services
# Industrie: Advertising Agencies
# Prix actuel: 30.0
# PER (Price-to-Earnings): 20.134228
# Ratio cours/valeur comptable (P/B): 3.9200313
# Croissance du chiffre d'affaires: 0.012
# Rendement du dividende: None
# ROE (Return on Equity): 0.26943

# %%
# # Construction de la table avec yfinance

# donnees = []

# for s in tqdm(stocks):
#     try :
#         ticker = all_stocks[s]
#         tick = yf.Ticker(ticker)
#         info = tick.info

#         # Extraire les paramètres 
#         PE = info.get('trailingPE', None)
#         ROE = info.get('returnOnEquity', None)
#         growth = info.get('revenueGrowth', None)
#         div = info.get('dividendYield', None)
#         sec = info.get('sector',None)
#         PB = info.get('priceToBook',None)
#         beta = info.get('beta', None)
             

#         donnees.append([s, PE, ROE, growth, div,sec,PB,beta])
        
#     except Exception as e:
#         print(f"Erreur avec {s}: {e}")
#     time.sleep(1)
# param = pd.DataFrame(donnees, columns=['Entreprise', 'PER', 'ROE', 'Croissance CA', 'Dividende','Secteur','PB','beta'])
# param.set_index('Entreprise', inplace=True)
# Out:
#   0%|                                                                                          | 0/748 [00:00<?, ?it/s]
# Erreur avec EURONEXT 100: 'EURONEXT 100'
# 100%|███████████████████████████████████████████████████████████████████████████████▉| 747/748 [14:03<00:01,  1.12s/it]
# Erreur avec Obli: 'Obli'
# 100%|████████████████████████████████████████████████████████████████████████████████| 748/748 [14:04<00:00,  1.13s/it]

# %%
# #On sauvegarde aussi la table en local pour pouvoir l'utiliser rapidement

# param.to_csv(r'C:\Users\ludo1\OneDrive\Documents\Centrale\Portfolio_management\param.csv', index=True)

# %% [markdown]
# ### On utilise la table de parametres sauvegardée

# %%
param = pd.read_csv(path_param)

param.index = param['Entreprise']
param = param.iloc[:,1:]
param.head()
# Out:
#                      PER      ROE  Croissance CA  Dividende  \
# Entreprise
# 1000Mercis     20.134228  0.26943          0.012        NaN
# 2Crsi                NaN      NaN         -0.883     0.1042
# A.S.T. Groupe        NaN -0.87685          0.211        NaN
# Ab Science           NaN      NaN          0.250        NaN
# Abc Arbitrage  17.089285  0.10401          0.126     0.0839
#
#                               Secteur        PB   beta
# Entreprise
# 1000Mercis     Communication Services  3.920031  0.643
# 2Crsi                      Technology  2.018682  2.708
# A.S.T. Groupe       Consumer Cyclical  0.436594  1.418
# Ab Science                 Healthcare       NaN  1.193
# Abc Arbitrage      Financial Services  1.797521  0.247

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=param, x='Secteur', palette='pastel', order=param['Secteur'].value_counts().index)

plt.title("Repartition de l'univers")
plt.xlabel("Secteur")
plt.ylabel("Nombre d'entreprises")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# On enleve les valeurs inscencées de la table

param = param[(param['beta'] >= -5) & (param['beta'] <= 10)]
param = param[(param['PB'] >= -10) & (param['PB'] <= 10)]
param = param[(param['ROE'] >= -1) & (param['ROE'] <= 1)]
param = param[(param['Croissance CA'] >= -1) & (param['Croissance CA'] <= 1.5)]

print(len(param))
# Out:
# 414

# %% [markdown]
# ### Qq plot sur toutes les entreprises récupéres

# %%
# Choisir la variable d'intéret parmis: PER	ROE	Croissance CA	Dividende PB	beta
var = 'PB'

plt.figure(figsize=(8, 6))
sns.histplot(param[var].dropna(), bins=100, kde=False, color='skyblue')
#plt.xlim(-1, 8)
mediane_roe = param[var].dropna().median()
plt.axvline(mediane_roe, color='red', linestyle='--', label=f'Médiane: {mediane_roe:.2f}')


plt.title(f'Répartition du {var} des entreprises')
plt.xlabel(var)
plt.ylabel("Nombre d'entreprises")
plt.legend()
plt.show()

# %% [markdown]
# ### Selection des entreprises en fonction de leurs caractéristiques

# %%
# Sélection des actions contracyclique
safe_sectors = ['Consumer Defensive', 'Healthcare', 'Utilities']

actions_contracy = param[(param['beta'] < 0.5) & 
                         (param['beta'] >= -1) &
                         (param['ROE'] >= 0.10) &
                         (param['Secteur'].isin(safe_sectors))
                        ].index.tolist()
len(actions_contracy)
# Out:
# 7

# %%
# Sélection des actions growth

actions_growth = param[ 
    (param['ROE'] > 0.15) & 
    (param['Croissance CA'] > 0.07)
].index.tolist()

len(actions_growth)
# Out:
# 29

# %%
#Selection des actions value
actions_value = param[ 
    (param['PB'] <= 1.5) & 
    (param['ROE'].between(0.10, 0.20)) & 
    (param['beta'].between(0.5, 1.5))
].index.tolist()

len(actions_value)
# Out:
# 38

# %%
obligations = ['Obli']

# %% [markdown]
# ### La répartition sectorielle dans le portfolio

# %%
secteurs = param.loc[actions_contracy + actions_value + actions_growth, 'Secteur']

secteurs_count = secteurs.value_counts()

#Cmaenbert
plt.figure(figsize=(10, 6))
plt.pie(secteurs_count, labels=secteurs_count.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel', len(secteurs_count)))

plt.title("Répartition du Portfolio par Secteur")
plt.axis('equal')  # Pour un camembert circulaire
plt.show()

# %% [markdown]
# ### Calcul des indicateurs clés du portfolio

# %% [markdown]
# #### Sélection de la fenetre de temps

# %%
# 0 -> 02/2000; 48 -> 04/2004 ; 120 -> 01/2010; 180 -> 2015; 240 -> 2020; 298 -> 11/2024

start = 230
end = 298

date = rendements.index[start:end]
print (f'Etude du {date[0]} au {date[-1]}')
# Out:
# Etude du 2019-04-30 au 2024-11-30

# %%
poids = {
    "growth": 0.2,
    "value": 0.4,
    "contracyclique": 0.2,
    "obligations": 0.2
}

# %%
# Rendement mensuels

rendement = (
    rendements.loc[date, actions_growth].mean(axis=1) * poids["growth"] +
    rendements.loc[date,actions_value].mean(axis=1) * poids["value"] +
    rendements.loc[date,actions_contracy].mean(axis=1) * poids["contracyclique"] +
    rendements.loc[date,obligations].mean(axis=1) * poids["obligations"]
)

# %% [markdown]
# ### Calcul des indices (rendements/vol/sharpe/VaR) pour le portfolio

# %%
# Valeur du portfolio dans le temps

valeur = (1 + rendement).cumprod()

#Calcul du rendement annualisé
perf = valeur.iloc[-1] - 1
perf_an = (1 + perf) ** (12 / len(date)) - 1
print(f'rendement annualisé : {perf_an}')

#Calcul de la volatilité annualisé 
vol = rendement.std() * np.sqrt(12)
print (f'volatilité : {vol}')

#ratio de sharpe
taux_sans_risque = 0.02  # Exemple annuel
sharpe = (rendement.mean() * 12 - taux_sans_risque) / vol
print (f'Sharpe : {sharpe}')

#Calcul VaR
var = -(perf_an/12 + 1.645*vol/np.sqrt(12))
print (f'VaR mensuelle : {var}')
# Out:
# rendement annualisé : 0.07829233779624811
# volatilité : 0.10260831198617743
# Sharpe : 0.5946966331205807
# VaR mensuelle : -0.05525003179236283

# %% [markdown]
# ### Calcul des indices (rendements/vol/sharpe/VaR) pour Euronext 100

# %%
euro100 = rendements.loc[date,'EURONEXT 100']
v100 = (1+euro100).cumprod()
perf100 = v100.iloc[-1] - 1
perf_an100 = (1 + perf100) ** (12 / len(date)) - 1

vol100 = euro100.std() * np.sqrt(12)
print(f'rendement annualisé : {perf_an100}')
print (f'volatilité : {vol100}')

taux_sans_risque = 0.02  # Exemple annuel
sharpe100 = (euro100.mean() * 12 - taux_sans_risque) / vol100
print (f'Sharpe : {sharpe100}')

#Calcul VaR
var100 = -(perf_an100/12 + 1.645*vol100/np.sqrt(12))
print (f'VaR : {var100}')
# Out:
# rendement annualisé : 0.061067356903222736
# volatilité : 0.14277275958191052
# Sharpe : 0.35152587435655147
# VaR : -0.07288753190214645

# %%
## Comparaison avec le CAC40
# CAC = rendements.loc[date,'CAC40']
# v100 = (1+euro100).cumprod()
# perf100 = v100.iloc[-1] - 1
# perf_an100 = (1 + perf100) ** (12 / len(date)) - 1

# vol100 = euro100.std() * np.sqrt(12)
# print(f'rendement annualisé : {perf_an100}')
# print (f'volatilité : {vol100}')

# %% [markdown]
# ### Plot de la performance du portefeuille sur les dates définies

# %%
plt.figure(figsize=(10, 6))
plt.plot(valeur, label="Portefeuille")
plt.plot(v100, label="EURONEXT 100")
plt.title("Performance du Portefeuille")
plt.xlabel("Date")
plt.ylabel("Valeur cumulée")
plt.legend()
plt.show()
